# %% [markdown]
# <a href="https://colab.research.google.com/github/ayoolafelix/Covid-19/blob/master/Nigeria_Covid_19_Data_%26_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import pandas as pd
import csv
import requests
import numpy as np 
from PIL import Image 
import matplotlib.pyplot as plt
import folium

url = 'https://covid19.ncdc.gov.ng/'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

dfs = pd.read_html(r.text)
tables = []
for df in dfs:
    tables.append(df)
data = pd.DataFrame(tables[0])
data
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  ...  No. Discharged  No. of Deaths
# 0            Lagos                         17764  ...           15209            202
# 1              FCT                          4969  ...            1426             46
# 2              Oyo                          3036  ...            1664             34
# 3              Edo                          2520  ...            2221            100
# 4          Plateau                          2113  ...            1063             29
# 5           Rivers                          2048  ...            1882             57
# 6           Kaduna                          1999  ...            1739             12
# 7             Kano                          1704  ...            1411             54
# 8            Delta                          1701  ...            1497             46
# 9             Ogun                          1600  ...            1410             26
# ...

# %%
#data.set_index('States Affected', inplace = True)

# %%
data
# Out:
#    States Affected  No. of Cases (Lab Confirmed)  ...  No. Discharged  No. of Deaths
# 0            Lagos                         17764  ...           15209            202
# 1              FCT                          4969  ...            1426             46
# 2              Oyo                          3036  ...            1664             34
# 3              Edo                          2520  ...            2221            100
# 4          Plateau                          2113  ...            1063             29
# 5           Rivers                          2048  ...            1882             57
# 6           Kaduna                          1999  ...            1739             12
# 7             Kano                          1704  ...            1411             54
# 8            Delta                          1701  ...            1497             46
# 9             Ogun                          1600  ...            1410             26
# ...

# %%
# download countries geojson file
# !wget --quiet  https://data.humdata.org/dataset/e66dbc70-17fe-4230-b9d6-855d192fc05c/resource/83dba4b0-992f-4748-b037-4b55ecc0c3b4/download/nigeria_lga.json -O nigeria.json
    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
nigeria_geo = r'nigeria.json' # geojson file

# create a plain sanfrancisco map
nigeria_map = folium.Map(location=[9.081999, 8.675277], zoom_start=12, tiles='Mapbox Bright')

# %%
nigeria_map.choropleth(
    geo_data=nigeria_geo,
    data=df,
    columns=['States Affected', 'No. of Cases (on admission)'],
    key_on='feature.properties.NAME_1',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Active Covid-19 Cases in Nigeria'
)

# display map
nigeria_map
# Out:
# /usr/local/lib/python3.6/dist-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
